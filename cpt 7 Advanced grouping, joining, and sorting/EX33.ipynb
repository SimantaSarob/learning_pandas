# %%
import pandas as pd

# %%
df = pd.read_csv('../data/sat-scores.csv',
                usecols=['Year', 'State.Code', 'Total.Math', 
                         'Family Income.Less than 20k.Math', 
                         'Family Income.Between 20-40k.Math', 
                         'Family Income.Between 40-60k.Math', 
                         'Family Income.Between 60-80k.Math',
                         'Family Income.Between 80-100k.Math',
                         'Family Income.More than 100k.Math'])
df.head()
# Out:
#    Year State.Code  Total.Math  Family Income.Between 20-40k.Math  \
# 0  2005         AL         559                                513
# 1  2005         AK         519                                492
# 2  2005         AZ         530                                498
# 3  2005         AR         552                                513
# 4  2005         CA         522                                477
#
#    Family Income.Between 40-60k.Math  Family Income.Between 60-80k.Math  \
# 0                                539                                550
# 1                                517                                513
# 2                                520                                524
# 3                                543                                553
# 4                                506                                521
#
#    Family Income.Between 80-100k.Math  Family Income.Less than 20k.Math  \
# 0                                 566                               462
# 1                                 528                               464
# 2                                 534                               485
# 3                                 570                               489
# 4                                 535                               451
#
#    Family Income.More than 100k.Math
# 0                                588
# 1                                541
# 2                                554
# 3                                572
# 4                                566

# %%
df.groupby('Year').mean(numeric_only=True).sort_index()
# Out:
#       Total.Math  Family Income.Between 20-40k.Math  \
# Year
# 2005  535.653846                         488.653846
# 2006  537.480769                         502.923077
# 2007  535.339623                         494.849057
# 2008  535.981132                         523.622642
# 2009  540.803922                         527.823529
# 2010  540.843137                         499.274510
# 2011  533.226415                         494.886792
# 2012  533.603774                         492.056604
# 2013  532.622642                         490.132075
# 2014  534.283019                         497.641509
# 2015  533.094340                         491.603774
#
#       Family Income.Between 40-60k.Math  Family Income.Between 60-80k.Math  \
# Year
# 2005                         522.673077                         536.076923
# 2006                         523.769231                         534.903846
# 2007                         519.490566                         533.188679
# 2008                         547.471698                         549.188679
# 2009                         550.980392                         553.941176
# 2010                         522.000000                         534.235294
# 2011                         513.415094                         528.660377
# 2012                         512.452830                         525.773585
# 2013                         511.377358                         520.320755
# 2014                         514.943396                         527.169811
# 2015                         513.754717                         527.132075
#
#       Family Income.Between 80-100k.Math  Family Income.Less than 20k.Math  \
# Year
# 2005                          548.942308                        427.596154
# 2006                          550.461538                        461.019231
# 2007                          545.698113                        457.924528
# 2008                          557.641509                        478.641509
# 2009                          565.333333                        482.058824
# 2010                          547.627451                        477.039216
# 2011                          541.849057                        460.452830
# 2012                          538.301887                        458.773585
# 2013                          537.396226                        469.358491
# 2014                          543.132075                        459.415094
# 2015                          542.037736                        447.490566
#
#       Family Income.More than 100k.Math
# Year
# 2005                         572.173077
# 2006                         572.519231
# 2007                         565.169811
# 2008                         564.566038
# 2009                         585.784314
# 2010                         569.274510
# 2011                         563.245283
# 2012                         557.320755
# 2013                         556.339623
# 2014                         555.433962
# 2015                         563.433962

# %%
df = df.rename(
columns={
'Family Income.Less than 20k.Math':'income<20k',
'Family Income.Between 20-40k.Math':'20k<income<40k',
'Family Income.Between 40-60k.Math':'40k<income<60k',
'Family Income.Between 60-80k.Math':'60k<income<80k',
'Family Income.Between 80-100k.Math':'80k<income<100k',
'Family Income.More than 100k.Math':'income>100k'
})
df.groupby('Year').mean(numeric_only=True).sort_index()
# Out:
#       Total.Math  20k<income<40k  40k<income<60k  60k<income<80k  \
# Year
# 2005  535.653846      488.653846      522.673077      536.076923
# 2006  537.480769      502.923077      523.769231      534.903846
# 2007  535.339623      494.849057      519.490566      533.188679
# 2008  535.981132      523.622642      547.471698      549.188679
# 2009  540.803922      527.823529      550.980392      553.941176
# 2010  540.843137      499.274510      522.000000      534.235294
# 2011  533.226415      494.886792      513.415094      528.660377
# 2012  533.603774      492.056604      512.452830      525.773585
# 2013  532.622642      490.132075      511.377358      520.320755
# 2014  534.283019      497.641509      514.943396      527.169811
# 2015  533.094340      491.603774      513.754717      527.132075
#
#       80k<income<100k  income<20k  income>100k
# Year
# 2005       548.942308  427.596154   572.173077
# 2006       550.461538  461.019231   572.519231
# 2007       545.698113  457.924528   565.169811
# 2008       557.641509  478.641509   564.566038
# 2009       565.333333  482.058824   585.784314
# 2010       547.627451  477.039216   569.274510
# 2011       541.849057  460.452830   563.245283
# 2012       538.301887  458.773585   557.320755
# 2013       537.396226  469.358491   556.339623
# 2014       543.132075  459.415094   555.433962
# 2015       542.037736  447.490566   563.433962

# %%
df.groupby('Year')[['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']].mean().T
# Out:
# Year                   2005        2006        2007        2008        2009  \
# income<20k       427.596154  461.019231  457.924528  478.641509  482.058824
# 20k<income<40k   488.653846  502.923077  494.849057  523.622642  527.823529
# 40k<income<60k   522.673077  523.769231  519.490566  547.471698  550.980392
# 60k<income<80k   536.076923  534.903846  533.188679  549.188679  553.941176
# 80k<income<100k  548.942308  550.461538  545.698113  557.641509  565.333333
# income>100k      572.173077  572.519231  565.169811  564.566038  585.784314
#
# Year                   2010        2011        2012        2013        2014  \
# income<20k       477.039216  460.452830  458.773585  469.358491  459.415094
# 20k<income<40k   499.274510  494.886792  492.056604  490.132075  497.641509
# 40k<income<60k   522.000000  513.415094  512.452830  511.377358  514.943396
# 60k<income<80k   534.235294  528.660377  525.773585  520.320755  527.169811
# 80k<income<100k  547.627451  541.849057  538.301887  537.396226  543.132075
# income>100k      569.274510  563.245283  557.320755  556.339623  555.433962
#
# Year                   2015
# income<20k       447.490566
# 20k<income<40k   491.603774
# 40k<income<60k   513.754717
# 60k<income<80k   527.132075
# 80k<income<100k  542.037736
# income>100k      563.433962

# %%
(
    df
    .groupby('Year')
    [['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']]
    .mean()
)
# Out:
#       income<20k  20k<income<40k  40k<income<60k  60k<income<80k  \
# Year
# 2005  427.596154      488.653846      522.673077      536.076923
# 2006  461.019231      502.923077      523.769231      534.903846
# 2007  457.924528      494.849057      519.490566      533.188679
# 2008  478.641509      523.622642      547.471698      549.188679
# 2009  482.058824      527.823529      550.980392      553.941176
# 2010  477.039216      499.274510      522.000000      534.235294
# 2011  460.452830      494.886792      513.415094      528.660377
# 2012  458.773585      492.056604      512.452830      525.773585
# 2013  469.358491      490.132075      511.377358      520.320755
# 2014  459.415094      497.641509      514.943396      527.169811
# 2015  447.490566      491.603774      513.754717      527.132075
#
#       80k<income<100k  income>100k
# Year
# 2005       548.942308   572.173077
# 2006       550.461538   572.519231
# 2007       545.698113   565.169811
# 2008       557.641509   564.566038
# 2009       565.333333   585.784314
# 2010       547.627451   569.274510
# 2011       541.849057   563.245283
# 2012       538.301887   557.320755
# 2013       537.396226   556.339623
# 2014       543.132075   555.433962
# 2015       542.037736   563.433962

# %%
(
    df
    .groupby('Year')
    [['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']]
    .mean()
    .T
)
# Out:
# Year                   2005        2006        2007        2008        2009  \
# income<20k       427.596154  461.019231  457.924528  478.641509  482.058824
# 20k<income<40k   488.653846  502.923077  494.849057  523.622642  527.823529
# 40k<income<60k   522.673077  523.769231  519.490566  547.471698  550.980392
# 60k<income<80k   536.076923  534.903846  533.188679  549.188679  553.941176
# 80k<income<100k  548.942308  550.461538  545.698113  557.641509  565.333333
# income>100k      572.173077  572.519231  565.169811  564.566038  585.784314
#
# Year                   2010        2011        2012        2013        2014  \
# income<20k       477.039216  460.452830  458.773585  469.358491  459.415094
# 20k<income<40k   499.274510  494.886792  492.056604  490.132075  497.641509
# 40k<income<60k   522.000000  513.415094  512.452830  511.377358  514.943396
# 60k<income<80k   534.235294  528.660377  525.773585  520.320755  527.169811
# 80k<income<100k  547.627451  541.849057  538.301887  537.396226  543.132075
# income>100k      569.274510  563.245283  557.320755  556.339623  555.433962
#
# Year                   2015
# income<20k       447.490566
# 20k<income<40k   491.603774
# 40k<income<60k   513.754717
# 60k<income<80k   527.132075
# 80k<income<100k  542.037736
# income>100k      563.433962

# %%
(
    df
    .groupby('Year')
    [['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']]
    .mean()
    .T
    .pct_change()
)
# Out:
# Year                 2005      2006      2007      2008      2009      2010  \
# income<20k            NaN       NaN       NaN       NaN       NaN       NaN
# 20k<income<40k   0.142793  0.090894  0.080635  0.093977  0.094936  0.046611
# 40k<income<60k   0.069618  0.041450  0.049796  0.045546  0.043872  0.045517
# 60k<income<80k   0.025645  0.021259  0.026368  0.003136  0.005374  0.023439
# 80k<income<100k  0.023999  0.029085  0.023462  0.015391  0.020566  0.025068
# income>100k      0.042319  0.040071  0.035682  0.012418  0.036175  0.039529
#
# Year                 2011      2012      2013      2014      2015
# income<20k            NaN       NaN       NaN       NaN       NaN
# 20k<income<40k   0.074783  0.072548  0.044260  0.083207  0.098579
# 40k<income<60k   0.037439  0.041451  0.043346  0.034768  0.045059
# 60k<income<80k   0.029694  0.025994  0.017489  0.023743  0.026038
# 80k<income<100k  0.024947  0.023828  0.032817  0.030279  0.028277
# income>100k      0.039487  0.035331  0.035250  0.022650  0.039474

# %%
(
    df
    .groupby('Year')
    [['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']]
    .mean()
    .T
    .pct_change()
    .T
)
# Out:
#       income<20k  20k<income<40k  40k<income<60k  60k<income<80k  \
# Year
# 2005         NaN        0.142793        0.069618        0.025645
# 2006         NaN        0.090894        0.041450        0.021259
# 2007         NaN        0.080635        0.049796        0.026368
# 2008         NaN        0.093977        0.045546        0.003136
# 2009         NaN        0.094936        0.043872        0.005374
# 2010         NaN        0.046611        0.045517        0.023439
# 2011         NaN        0.074783        0.037439        0.029694
# 2012         NaN        0.072548        0.041451        0.025994
# 2013         NaN        0.044260        0.043346        0.017489
# 2014         NaN        0.083207        0.034768        0.023743
# 2015         NaN        0.098579        0.045059        0.026038
#
#       80k<income<100k  income>100k
# Year
# 2005         0.023999     0.042319
# 2006         0.029085     0.040071
# 2007         0.023462     0.035682
# 2008         0.015391     0.012418
# 2009         0.020566     0.036175
# 2010         0.025068     0.039529
# 2011         0.024947     0.039487
# 2012         0.023828     0.035331
# 2013         0.032817     0.035250
# 2014         0.030279     0.022650
# 2015         0.028277     0.039474

# %%
(
    df
    .groupby('Year')
    [['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']]
    .mean()
    .T
    .pct_change()
    .T
    .mean()
)
# Out:
# income<20k              NaN
# 20k<income<40k     0.083929
# 40k<income<60k     0.045260
# 60k<income<80k     0.020744
# 80k<income<100k    0.025247
# income>100k        0.034399
# dtype: float64

# %%
(
    df
    .groupby('Year')
    [['income<20k',
    '20k<income<40k',
    '40k<income<60k',
    '60k<income<80k',
    '80k<income<100k',
    'income>100k']]
    .mean()
    .T
    .pct_change()
    .T
    .mean()
    .sort_values(ascending=False)
    .head()
)
# Out:
# 20k<income<40k     0.083929
# 40k<income<60k     0.045260
# income>100k        0.034399
# 80k<income<100k    0.025247
# 60k<income<80k     0.020744
# dtype: float64

# %%
(
    df
    .groupby('Year')
    [['income<20k',                    
        '20k<income<40k',
        '40k<income<60k',
        '60k<income<80k',
        '80k<income<100k',
        'income>100k']]
    .mean()
    .T
    .pct_change()
    .T
    .describe()
)
# Out:
#        income<20k  20k<income<40k  40k<income<60k  60k<income<80k  \
# count         0.0       11.000000       11.000000       11.000000
# mean          NaN        0.083929        0.045260        0.020744
# std           NaN        0.026723        0.009055        0.008745
# min           NaN        0.044260        0.034768        0.003136
# 25%           NaN        0.073665        0.041450        0.019374
# 50%           NaN        0.083207        0.043872        0.023743
# 75%           NaN        0.094456        0.045532        0.026016
# max           NaN        0.142793        0.069618        0.029694
#
#        80k<income<100k  income>100k
# count        11.000000    11.000000
# mean          0.025247     0.034399
# std           0.004821     0.008947
# min           0.015391     0.012418
# 25%           0.023645     0.035291
# 50%           0.024947     0.036175
# 75%           0.028681     0.039508
# max           0.032817     0.042319

# %%
df['diff'] = (df['income>100k'] - df['income<20k'])


(   
    df
    .groupby('State.Code')
    ['diff']
    .mean()
    .sort_values(ascending=False)
    .head()
)
# Out:
# State.Code
# ND    341.909091
# WY    246.454545
# DC    208.818182
# SD    157.000000
# MS    140.000000
# Name: diff, dtype: float64
