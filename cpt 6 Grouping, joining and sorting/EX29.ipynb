# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/nyc_taxi_2019-01.csv',
                 usecols=['passenger_count',
                          'trip_distance',
                          'total_amount'])
df.head(10)
# Out:
#    passenger_count  trip_distance  total_amount
# 0                1            1.5          9.95
# 1                1            2.6         16.30
# 2                3            0.0          5.80
# 3                5            0.0          7.55
# 4                5            0.0         55.55
# 5                5            0.0         13.31
# 6                5            0.0         55.55
# 7                1            1.3          9.05
# 8                1            3.7         18.50
# 9                2            2.1         13.00

# %%
#df.info()

# %%
#df['passenger_count'] = df['passenger_count'].astype(np.int8)
#df['trip_distance'] = df['trip_distance'].astype(np.float16)
#df['total_amount'] = df['trip_distance'].astype(np.float16)
#df.info()

# %%
df.sort_values('trip_distance',ascending= False)['total_amount'].head(20).mean()
# Out:
# np.float64(290.00999999999993)

# %%
df.sort_values(['passenger_count', 'trip_distance'],
                ascending=[True, False])['total_amount'].iloc[:50].mean()
# Out:
# np.float64(135.49739999999997)

# %%
# In which five rides did people pay the most per mile?

df = df[df['trip_distance'] != 0]
df['cost_per_mile'] = df['total_amount'] / df['trip_distance']
df.sort_values('cost_per_mile').tail(5)
# Out:
#          passenger_count  trip_distance  total_amount  cost_per_mile
# 4136499                1           0.01        273.96   27396.000000
# 6403254                1           0.01        322.30   32230.000000
# 7099014                4           0.01        415.30   41530.000000
# 478791                 1           0.10       6667.45   66674.500000
# 2499600                1           2.40     623261.66  259692.358333

# %%
# Let's assume that multi-passenger rides are split evenly among the passengers. 
# Given that assumption, in which 10 rides did each individual pay the greatest amount? 
# And again, how far did they travel?



df = df[df['passenger_count'] >= 2]
df['payment_per_person'] = df['total_amount'] / df['passenger_count']
df.sort_values('payment_per_person').tail(10)
# Out:
#          passenger_count  trip_distance  total_amount  cost_per_mile  \
# 5031491                2          64.30        343.32       5.339347
# 4563340                2           0.40        350.30     875.750000
# 4202883                2          60.23        369.06       6.127511
# 4751745                2         100.78        403.50       4.003771
# 5726185                2          65.05        416.82       6.407686
# 149362                 2          17.20        426.80      24.813953
# 7593395                2          83.61        449.32       5.373998
# 3842620                2         110.04        515.82       4.687568
# 3014027                2          16.60        560.76      33.780723
# 2972145                2          19.90        589.96      29.646231
#
#          payment_per_person
# 5031491              171.66
# 4563340              175.15
# 4202883              184.53
# 4751745              201.75
# 5726185              208.41
# 149362               213.40
# ...
