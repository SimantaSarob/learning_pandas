# %% [markdown]
# ## Cities
#
# from exercise 20.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('../data/cities.json')
df.head()
# Out:
#            city growth_from_2000_to_2013   latitude   longitude  population  \
# 0      New York                     4.8%  40.712784  -74.005941     8405837
# 1   Los Angeles                     4.8%  34.052234 -118.243685     3884307
# 2       Chicago                    -6.1%  41.878114  -87.629798     2718782
# 3       Houston                    11.0%  29.760427  -95.369803     2195914
# 4  Philadelphia                     2.6%  39.952584  -75.165222     1553165
#
#    rank         state
# 0     1      New York
# 1     2    California
# 2     3      Illinois
# 3     4         Texas
# 4     5  Pennsylvania

# %%
df.groupby('state')['city'].count()
# Out:
# state
# Alabama                  12
# Alaska                    1
# Arizona                  25
# Arkansas                 10
# California              212
# Colorado                 21
# Connecticut              15
# Delaware                  2
# District of Columbia      1
# Florida                  73
# Georgia                  18
# Hawaii                    1
# Idaho                     8
# Illinois                 52
# Indiana                  21
# Iowa                     13
# Kansas                   11
# Kentucky                  5
# Louisiana                 9
# Maine                     1
# Maryland                  7
# Massachusetts            36
# Michigan                 31
# Minnesota                24
# Mississippi               6
# Missouri                 16
# Montana                   4
# Nebraska                  4
# Nevada                    6
# New Hampshire             3
# New Jersey               22
# New Mexico                7
# New York                 17
# ...

# %%
df.groupby('state')['city'].count().sort_values().plot.bar()
# Out:
# <Axes: xlabel='state'>

# %%
df.groupby('state')['city'].count().sort_values().plot.bar(figsize = (10,10)) # size in inch.
# Out:
# <Axes: xlabel='state'>

# %%
df.loc[df['state'] == 'Pennsylvania', ['city', 'growth_from_2000_to_2013']].set_index('city')
# Out:
#               growth_from_2000_to_2013
# city
# Philadelphia                      2.6%
# Pittsburgh                       -8.3%
# Allentown                        11.2%
# Erie                             -2.8%
# Reading                           8.0%
# Scranton                          0.0%
# Bethlehem                         5.2%
# Lancaster                         4.5%
# Harrisburg                        0.6%
# Altoona                          -7.3%
# York                              6.4%
# State College                     8.7%
# Wilkes-Barre                     -4.3%

# %%
df.loc[df['state'] == 'Pennsylvania', ['city', 'growth_from_2000_to_2013']].set_index('city')['growth_from_2000_to_2013']
# Out:
# city
# Philadelphia      2.6%
# Pittsburgh       -8.3%
# Allentown        11.2%
# Erie             -2.8%
# Reading           8.0%
# Scranton          0.0%
# Bethlehem         5.2%
# Lancaster         4.5%
# Harrisburg        0.6%
# Altoona          -7.3%
# York              6.4%
# State College     8.7%
# Wilkes-Barre     -4.3%
# Name: growth_from_2000_to_2013, dtype: object

# %%
df.loc[df['state'] == 'Pennsylvania', ['city', 'growth_from_2000_to_2013']].set_index('city')['growth_from_2000_to_2013'].str.replace('%','').astype(np.float32).sort_values()
# Out:
# city
# Pittsburgh       -8.3
# Altoona          -7.3
# Wilkes-Barre     -4.3
# Erie             -2.8
# Scranton          0.0
# Harrisburg        0.6
# Philadelphia      2.6
# Lancaster         4.5
# Bethlehem         5.2
# York              6.4
# Reading           8.0
# State College     8.7
# Allentown        11.2
# Name: growth_from_2000_to_2013, dtype: float32

# %%
df.loc[df['state'] == 'Pennsylvania', ['city', 'growth_from_2000_to_2013']].set_index('city')['growth_from_2000_to_2013'].str.replace('%','').astype(np.float32).sort_values().plot.bar(figsize = (12,12))
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# find all cities in Massachusetts and create a pie plot with all these cities

# %%
df.loc[df['state'] == 'Massachusetts', ['city', 'population']].set_index('city')['population']
# Out:
# city
# Boston             645966
# Worcester          182544
# Springfield        153703
# Lowell             108861
# Cambridge          107289
# New Bedford         95078
# Brockton            94089
# Quincy              93494
# Lynn                91589
# Fall River          88697
# Newton              87971
# Somerville          78804
# Lawrence            77657
# Waltham             62227
# Haverhill           62088
# Malden              60509
# Medford             57170
# Taunton             56069
# Chicopee            55717
# Weymouth Town       55419
# Revere              53756
# Peabody             52044
# Methuen             48514
# Barnstable Town     44641
# Pittsfield          44057
# Attleboro           43886
# Everett             42935
# Salem               42544
# Westfield           41301
# Leominster          41002
# Beverly             40664
# Fitchburg           40383
# Holyoke             40249
# Marlborough         39414
# Woburn              39083
# ...

# %%
df.loc[df['state'] == 'Massachusetts', ['city', 'population']].set_index('city')['population'].plot.pie(figsize = (12,12))
# Out:
# <Axes: ylabel='population'>

# %%
df.groupby('state').count()
# Out:
#                       city  growth_from_2000_to_2013  latitude  longitude  \
# state
# Alabama                 12                        12        12         12
# Alaska                   1                         1         1          1
# Arizona                 25                        25        25         25
# Arkansas                10                        10        10         10
# California             212                       212       212        212
# Colorado                21                        21        21         21
# Connecticut             15                        15        15         15
# Delaware                 2                         2         2          2
# District of Columbia     1                         1         1          1
# Florida                 73                        73        73         73
# Georgia                 18                        18        18         18
# Hawaii                   1                         1         1          1
# ...

# %%
df[df['state'] == 'Idaho']
# Out:
#               city growth_from_2000_to_2013   latitude   longitude  \
# 97      Boise City                     9.5%  43.618710 -116.214607
# 360          Nampa                    57.9%  43.540717 -116.563462
# 380       Meridian                   127.6%  43.612109 -116.391513
# 619    Idaho Falls                    14.0%  43.491651 -112.033964
# 673      Pocatello                     5.4%  42.871303 -112.445534
# 762       Caldwell                    77.1%  43.662938 -116.687360
# 800  Coeur d'Alene                    32.8%  47.677683 -116.780466
# 807     Twin Falls                    31.5%  42.562967 -114.460871
#
#      population  rank  state
# 97       214237    98  Idaho
# 360       86518   361  Idaho
# 380       83596   381  Idaho
# 619       58292   620  Idaho
# 673       54350   674  Idaho
# 762       48957   763  Idaho
# 800       46402   801  Idaho
# 807       45981   808  Idaho

# %%
df.plot.scatter(x='longitude', y='latitude', figsize = (12,10))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>
