# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10, 15, 17, 20, 25, 28, 32, 7, 14, 24])
s.describe()
# Out:
# count    10.000000
# mean     19.200000
# std       8.038795
# min       7.000000
# 25%      14.250000
# 50%      18.500000
# 75%      24.750000
# max      32.000000
# dtype: float64

# %%
s.plot.box()
# Out:
# <Axes: >

# %%
s = pd.Series([-20, 10, 15, 17, 20, 25, 40])
print(s.describe())
print(s.plot.box(subplots=True))
# Out:
# count     7.000000
# mean     15.285714
# std      18.273061
# min     -20.000000
# 25%      12.500000
# 50%      17.000000
# 75%      22.500000
# max      40.000000
# dtype: float64
#     Axes(0.125,0.11;0.775x0.77)
# dtype: object
